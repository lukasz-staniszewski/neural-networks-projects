# %%
import torch
import numpy as np
import time
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## GPU

# %% [markdown]
# Jednym z kluczowych udogodnień pytorcha jest możliwość szybkiego i prostego przenoszenia obliczeń między CPU a GPU

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda") 
device
# Out:
# device(type='cuda')

# %%
x = torch.zeros(2, 3)
print("X", x)
x = x.to(device)
print("X", x)
# Out:
# X tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# X tensor([[0., 0., 0.],
#         [0., 0., 0.]], device='cuda:0')

# %% [markdown]
# #### Co nam to daje?

# %%
x = torch.randn(5000, 5000)

## CPU version
start_time = time.time()
_ = torch.matmul(x, x)
end_time = time.time()
print(f"CPU time: {(end_time - start_time):6.5f}s")

## GPU version
x = x.to(device)
# The first operation on a CUDA device can be slow as it has to establish a CPU-GPU communication first. 
# Hence, we run an arbitrary command first without timing it for a fair comparison.
_ = torch.matmul(x*0.0, x)
start_time = time.time()
_ = torch.matmul(x, x)
end_time = time.time()
print(f"GPU time: {(end_time - start_time):6.5f}s")
# Out:
# CPU time: 0.67921s
# GPU time: 0.00000s

# %% [markdown]
# #### Ciąg komend do zapisania
# Losowość jest bardzo ważnym elementem trenowania sieci neuronowych (o czym się wkrótce przekonamy). Eksperymentując, chcielibyśmy jednak żeby przy każdym uruchomieniu programu, wynik był taki sam. Tylko w takim przypadku jesteśmy w stanie coś wnioskować. Do zapewnienia możliwości reprodukcji wyników na GPU za pomocą pytorcha służa poniższe komendy:

# %%
# GPU operations have a separate seed we also want to set
if torch.cuda.is_available(): 
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    
# Additionally, some operations on a GPU are implemented stochastic for efficiency
# We want to ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.determinstic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Tworzenie modeli
# Tworzymy tensory z parametrami, wagi i biasy, obliczamy gradienty, aktualizujemy parametry itd.
# lub
# wykorzystujemy torch.nn

# %% [markdown]
# W torch.nn możemy znaleźć wiele przydatnych predefiniowanych klas jak wagi sieci, funkcje aktywacji, funkcje straty, optymalizacja itp. Jeszcze raz, dokumentacja jest fajna: https://pytorch.org/docs/stable/nn.html

# %%
import torch.nn as nn

# %% [markdown]
# Dodatkowo, funkcje wykorzystywane w budowaniu sieci znajdują się w module torch.nn.functionl

# %%
import torch.nn.functional as F

# %% [markdown]
# ### nn.Module
# W PyTorchu, sieci neuronowe są zbudowane z modułów - obiektów klas dziedziczących po klasie nn.Module. Moduły mogą składać się z innych modułów, a sieć neuronowa w całości też zazwyczaj jest modułem.
#
# Podstawowy template dla modułu wygląda następująco

# %%
class MyModule(nn.Module):
    
    def __init__(self):
        super().__init__()
        # Some init for my module
        
    def forward(self, x):
        # Function for performing the calculation of the module.
        pass

# %% [markdown]
# W konstruktorze modułu zazwyczaj inicjowane są wszystkie parametry, lub wewnętrzne moduły (np. warstwy sieci)
#
# W funkcji forward zapisane są wszystkie obliczenia które są wykonywane kiedy wywołujemy dany moduł. Przykładowo: (nn = MyModule(); nn(x)).
#
# Kalkulacja wstecz (backwards) jest tworzona automatycznie, ale w razie potrzeby można ją też nadpisywać

# %% [markdown]
# # Stwórzmy pierwsza sieć neuronową

# %%
class SimpleClassifier(nn.Module):

    def __init__(self, num_inputs, num_hidden, num_outputs):
        super().__init__()
        # Initialize the modules we need to build the network
        self.linear1 = nn.Linear(num_inputs, num_hidden)
        self.act_fn = nn.Tanh()
        self.linear2 = nn.Linear(num_hidden, num_outputs)

    def forward(self, x):
        # Perform the calculation of the model to determine the prediction
        x = self.linear1(x)
        x = self.act_fn(x)
        x = self.linear2(x)
        return x

# %% [markdown]
# Wypisywanie zawartości modelu

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
# Printing a module shows all its submodules
print(model)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %% [markdown]
# Co tak właściwie mamy w środku?

# %%
for name, param in model.named_parameters():
    print(f"Parameter {name}, shape {param.shape}")
# Out:
# Parameter linear1.weight, shape torch.Size([4, 2])
# Parameter linear1.bias, shape torch.Size([4])
# Parameter linear2.weight, shape torch.Size([1, 4])
# Parameter linear2.bias, shape torch.Size([1])

# %% [markdown]
# ## Activation functions

# %%
act_fn_by_name = {
    "sigmoid": torch.sigmoid,
    "tanh": torch.tanh,
    "relu": F.relu,
    "leakyrelu": F.leaky_relu
}

# %%
def get_grads(act_fn, x):
    x = x.clone().requires_grad_() # Mark the input as tensor for which we want to store gradients
    out = act_fn(x)
    out.sum().backward() # Summing results in an equal gradient flow to each element in x
    return x.grad # Accessing the gradients of x by "x.grad"

# %%
# %matplotlib inline
def vis_act_fn(act_fn, name, ax, x):
    # Run activation function
    y = act_fn(x)
    y_grads = get_grads(act_fn, x)
    # Push x, y and gradients back to cpu for plotting
    x, y, y_grads = x.cpu().numpy(), y.cpu().numpy(), y_grads.cpu().numpy()
    ## Plotting
    ax.plot(x, y, linewidth=2, label="ActFn")
    ax.plot(x, y_grads, linewidth=2, label="Gradient")
    ax.set_title(name)
    ax.legend()
    ax.set_ylim(-1.5, x.max())

x = torch.linspace(-5, 5, 1000) # Range on which we want to visualize the activation functions
## Plotting
rows = math.ceil(len(act_fn_by_name)/2.0)
fig, ax = plt.subplots(rows, 2, figsize=(8, rows*4))
for i, name in enumerate(act_fn_by_name.keys()):
    vis_act_fn(act_fn_by_name[name], name, ax[divmod(i,2)], x)
fig.subplots_adjust(hspace=0.3)
plt.show()
plt.close()

# %% [markdown]
# # Dane
# PyTorch posiada zaimplementowanych kilka funkcjonalności które pozwalają wczytywać i manipulować danymi. Znajdują się one w pakiecie torch.utils.data

# %%
import torch.utils.data as data

# %% [markdown]
# Główną strukturą w ramach której przechowywane (lub niekoniecznie) są dane jest klasa Dataset. Stwórzmy sobie przykładowy zbiór danych - tzw. ciągły XOR. Przykład zaczerpnięty z https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/tutorial2/Introduction_to_PyTorch.html#Learning-by-example:-Continuous-XOR

# %%
class XORDataset(data.Dataset):

    def __init__(self, size, std=0.1):
        """
        Inputs:
            size - Number of data points we want to generate
            std - Standard deviation of the noise (see generate_continuous_xor function)
        """
        super().__init__()
        self.size = size
        self.std = std
        self.generate_continuous_xor()

    def generate_continuous_xor(self):
        # Each data point in the XOR dataset has two variables, x and y, that can be either 0 or 1
        # The label is their XOR combination, i.e. 1 if only x or only y is 1 while the other is 0.
        # If x=y, the label is 0.
        data = torch.randint(low=0, high=2, size=(self.size, 2), dtype=torch.float32)
        label = (data.sum(dim=1) == 1).to(torch.long)
        # To make it slightly more challenging, we add a bit of gaussian noise to the data points.
        data += self.std * torch.randn(data.shape)

        self.data = data
        self.label = label

    def __len__(self):
        # Number of data point we have. Alternatively self.data.shape[0], or self.label.shape[0]
        return self.size

    def __getitem__(self, idx):
        # Return the idx-th data point of the dataset
        # If we have multiple things to return (data point and label), we can return them as tuple
        data_point = self.data[idx]
        data_label = self.label[idx]
        return data_point, data_label

# %%
dataset = XORDataset(size=200)
print("Size of dataset:", len(dataset))
print("Data point 0:", dataset[0])
# Out:
# Size of dataset: 200
# Data point 0: (tensor([-0.0786,  1.2195]), tensor(1))

# %%
examples = dataset.data
labels = dataset.label
data_0 = examples[labels == 0]
data_1 = examples[labels == 1]

plt.figure(figsize=(4,4))
plt.scatter(data_0[:,0], data_0[:,1], edgecolor="#333", label="Class 0")
plt.scatter(data_1[:,0], data_1[:,1], edgecolor="#333", label="Class 1")
plt.title("Dataset samples")
plt.legend()
plt.show()

# %% [markdown]
# ## Data loaders (Ładowacze danych?!)

# %%
data_loader = data.DataLoader(dataset,batch_size=8, shuffle=True)

# %%
next(iter(data_loader))
# Out:
# [tensor([[ 0.1207, -0.0057],
#          [ 1.1172,  1.0411],
#          [ 1.0062,  0.1106],
#          [-0.0596,  0.0083],
#          [ 0.9585,  0.8988],
#          [ 1.0260, -0.0541],
#          [-0.0797, -0.0801],
#          [ 1.1045,  0.2257]]),
#  tensor([0, 0, 1, 0, 0, 1, 0, 1])]

# %%
len(data_loader)
# Out:
# 25

# %%
next(iter(data_loader))[0].shape[0]*len(data_loader)
# Out:
# 200

# %%
data_loader_2 = data.DataLoader(dataset,batch_size=7, shuffle=True)
next(iter(data_loader_2))[0].shape[0]*len(data_loader_2)
# Out:
# 203

# %%
list(iter(data_loader_2))[-1]
# Out:
# [tensor([[ 0.8745, -0.0903],
#          [-0.0337, -0.1071],
#          [ 0.9348,  1.0307],
#          [ 1.1162,  1.0521]]),
#  tensor([1, 0, 0, 0])]

# %% [markdown]
# #### Drop last
# Parametr powodujący pominięcie ostatniego wsadu (batch)

# %%
data_loader_2 = data.DataLoader(dataset,batch_size=7, shuffle=True, drop_last=True)
next(iter(data_loader_2))[0].shape[0]*len(data_loader_2)
# Out:
# 196

# %% [markdown]
# ## Funkcje straty
# Na poprzednich zajęciach obliczaliśmy funkcję straty ręcznie wykonując operacje na tensorach. Jest to w pełni poprawne rozwiązanie, ale możemy też nie wymyślać koła na nowo, ale wykorzystać wbudowane moduły. Pełna lista dostępna tutaj: https://pytorch.org/docs/stable/nn.html#loss-functions

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tensor_1 = torch.arange(5)
tensor_2 = torch.ones(5)
print(tensor_1, tensor_2)
# Out:
# tensor([0, 1, 2, 3, 4]) tensor([1., 1., 1., 1., 1.])

# %% [markdown]
# ### Błąd średniokwadratowy (Mean Squared Error) lub L2Loss

# %%
loss = nn.MSELoss()
loss(tensor_1,tensor_2)
# Out:
# tensor(3.)

# %% [markdown]
# $ \quad l_{n}=\left(x_{n}-y_{n}\right)^{2}$

# %%
loss = nn.MSELoss(reduction="none")
print(f"No reduction: {loss(tensor_1,tensor_2)}")
loss = nn.MSELoss(reduction="mean")
print(f"Mean: {loss(tensor_1,tensor_2)}")
loss = nn.MSELoss(reduction="sum")
print(f"Sum: {loss(tensor_1,tensor_2)}")
# Out:
# No reduction: tensor([1., 0., 1., 4., 9.])
# Mean: 3.0
# Sum: 15.0

# %%
F.mse_loss(tensor_1, tensor_2)
# Out:
# tensor(3.)

# %%
loss = nn.MSELoss(reduction="none")
x, y = torch.meshgrid(torch.linspace(0,10,100),torch.linspace(0,10,100))
z = loss(x,y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(), y.numpy().flatten(), z.numpy().flatten(), linewidth=0.2, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="613.5652301117696">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_9800/1793820244.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ### Błąd bezwzględny (Mean absolute Error) lub L1Loss

# %% [markdown]
# $ \quad l_{n}=\left|x_{n}-y_{n}\right|$

# %%
tensor_1 = tensor_1.float()
print(tensor_1, tensor_2)
loss = nn.L1Loss()
loss(tensor_1,tensor_2)
# Out:
# tensor([0., 1., 2., 3., 4.]) tensor([1., 1., 1., 1., 1.])
# tensor(1.4000)

# %%
loss = nn.L1Loss(reduction="none")
print(f"No reduction: {loss(tensor_1,tensor_2)}")
loss = nn.L1Loss(reduction="mean")
print(f"Mean: {loss(tensor_1,tensor_2)}")
loss = nn.L1Loss(reduction="sum")
print(f"Sum: {loss(tensor_1,tensor_2)}")
# Out:
# No reduction: tensor([1., 0., 1., 2., 3.])
# Mean: 1.399999976158142
# Sum: 7.0

# %%
loss = nn.L1Loss(reduction="none")
x, y = torch.meshgrid(torch.linspace(0,10,100),torch.linspace(0,10,100))
z = loss(x,y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(), y.numpy().flatten(), z.numpy().flatten(), linewidth=0.2, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="613.5652301117696">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_9800/1058480425.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ### Entropia krzyżowa:
# $l_{n}=\left[y_{n} \cdot \log x_{n}+\left(1-y_{n}\right) \cdot \log \left(1-x_{n}\right)\right]$

# %%
tensor_1 = torch.rand(5)
tensor_2 = torch.ones(5)
print(tensor_1, tensor_2)
loss = nn.BCELoss(reduction="none")
loss(tensor_1,tensor_2)
# Out:
# tensor([0.7985, 0.0166, 0.3886, 0.4182, 0.7453]) tensor([1., 1., 1., 1., 1.])
# tensor([0.2250, 4.0966, 0.9451, 0.8719, 0.2940])

# %%
loss(tensor_1*10,tensor_2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9800/3052507462.py in <module>
# ----> 1 loss(tensor_1*10,tensor_2)
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     610
#     611     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 612         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     613
#     614
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2891         weight = weight.expand(new_size)
#    2892
# -> 2893     return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#    2894
#    2895
#
# RuntimeError: all elements of input should be between 0 and 1

# %%
loss(tensor_1,tensor_2)
# Out:
# tensor([0.2250, 4.0966, 0.9451, 0.8719, 0.2940])

# %%
loss = nn.BCEWithLogitsLoss(reduction="none")
loss(tensor_1*10,tensor_2)
# Out:
# tensor([3.4052e-04, 6.1345e-01, 2.0314e-02, 1.5160e-02, 5.7955e-04])

# %%
loss = nn.BCEWithLogitsLoss(reduction="none")
x, y = torch.meshgrid(torch.linspace(-10,10,100),torch.linspace(-10,10,100))
z = loss(x,y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(), y.numpy().flatten(), z.numpy().flatten(), linewidth=0.2, antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="613.5652301117696">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_9800/1858135863.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# # Optymalizacja parametrów
# W przykładowym problemie optymalizacji parametrów regresji, ręcznie aktualizowaliśmy gradienty. W torch są do tego narzędzia zwane optymalizatorami, znajdują się one w pakiecie torch.optim
#
# Najprostszym optymalizaotrem jest algorytm stochastycznego spadku gradientu (Stochastic Gradient Descent) - SGD

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
print(model)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1)

# %% [markdown]
# ## Połączmy to wszystko razem

# %%
train_dataset = XORDataset(size=1000)
train_data_loader = data.DataLoader(train_dataset, batch_size=128, shuffle=True)

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
model.to(device)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1)

# %%
loss_module = nn.BCEWithLogitsLoss()

# %%
model.train() 

# Training loop
for epoch in range(100):
    for data_inputs, data_labels in data_loader:

        ## Step 1: Move input data to device (only strictly necessary if we use GPU)
        data_inputs = data_inputs.to(device)
        data_labels = data_labels.to(device)

        ## Step 2: Run the model on the input data
        preds = model(data_inputs)
        preds = preds.squeeze(dim=1) # Output is [Batch size, 1], but we want [Batch size]

        ## Step 3: Calculate the loss
        loss = loss_module(preds, data_labels.float())

        ## Step 4: Perform backpropagation
        # Before calculating the gradients, we need to ensure that they are all zero. 
        # The gradients would not be overwritten, but actually added to the existing ones.
        optimizer.zero_grad() 
        # Perform backpropagation
        loss.backward()

        ## Step 5: Update the parameters
        optimizer.step()
    print(f"Epoch: {epoch}, loss: {loss.item():.3}")
# Out:
# Epoch: 0, loss: 0.662
# Epoch: 1, loss: 0.726
# Epoch: 2, loss: 0.675
# Epoch: 3, loss: 0.694
# Epoch: 4, loss: 0.705
# Epoch: 5, loss: 0.696
# Epoch: 6, loss: 0.705
# Epoch: 7, loss: 0.685
# Epoch: 8, loss: 0.68
# Epoch: 9, loss: 0.681
# Epoch: 10, loss: 0.689
# Epoch: 11, loss: 0.661
# Epoch: 12, loss: 0.687
# Epoch: 13, loss: 0.654
# Epoch: 14, loss: 0.631
# Epoch: 15, loss: 0.607
# Epoch: 16, loss: 0.602
# Epoch: 17, loss: 0.619
# Epoch: 18, loss: 0.578
# Epoch: 19, loss: 0.696
# Epoch: 20, loss: 0.56
# Epoch: 21, loss: 0.564
# Epoch: 22, loss: 0.581
# Epoch: 23, loss: 0.571
# Epoch: 24, loss: 0.421
# Epoch: 25, loss: 0.394
# Epoch: 26, loss: 0.417
# Epoch: 27, loss: 0.547
# Epoch: 28, loss: 0.368
# Epoch: 29, loss: 0.325
# Epoch: 30, loss: 0.225
# Epoch: 31, loss: 0.218
# Epoch: 32, loss: 0.225
# Epoch: 33, loss: 0.244
# Epoch: 34, loss: 0.24
# Epoch: 35, loss: 0.187
# Epoch: 36, loss: 0.215
# Epoch: 37, loss: 0.209
# Epoch: 38, loss: 0.164
# Epoch: 39, loss: 0.132
# Epoch: 40, loss: 0.167
# Epoch: 41, loss: 0.164
# Epoch: 42, loss: 0.0901
# Epoch: 43, loss: 0.071
# Epoch: 44, loss: 0.0935
# Epoch: 45, loss: 0.109
# Epoch: 46, loss: 0.0749
# Epoch: 47, loss: 0.107
# Epoch: 48, loss: 0.0645
# Epoch: 49, loss: 0.0502
# Epoch: 50, loss: 0.0652
# Epoch: 51, loss: 0.0524
# Epoch: 52, loss: 0.0413
# Epoch: 53, loss: 0.0546
# Epoch: 54, loss: 0.0493
# Epoch: 55, loss: 0.0419
# Epoch: 56, loss: 0.045
# Epoch: 57, loss: 0.0587
# Epoch: 58, loss: 0.0566
# Epoch: 59, loss: 0.0897
# Epoch: 60, loss: 0.0414
# Epoch: 61, loss: 0.0423
# Epoch: 62, loss: 0.0591
# Epoch: 63, loss: 0.0333
# Epoch: 64, loss: 0.0331
# Epoch: 65, loss: 0.041
# Epoch: 66, loss: 0.0273
# Epoch: 67, loss: 0.0292
# Epoch: 68, loss: 0.0649
# Epoch: 69, loss: 0.0365
# Epoch: 70, loss: 0.0376
# Epoch: 71, loss: 0.0253
# Epoch: 72, loss: 0.0439
# Epoch: 73, loss: 0.0552
# Epoch: 74, loss: 0.0375
# Epoch: 75, loss: 0.0281
# Epoch: 76, loss: 0.03
# Epoch: 77, loss: 0.0688
# Epoch: 78, loss: 0.0214
# Epoch: 79, loss: 0.0465
# Epoch: 80, loss: 0.0382
# Epoch: 81, loss: 0.0259
# Epoch: 82, loss: 0.0309
# Epoch: 83, loss: 0.0256
# Epoch: 84, loss: 0.0206
# Epoch: 85, loss: 0.0257
# Epoch: 86, loss: 0.0174
# Epoch: 87, loss: 0.0165
# Epoch: 88, loss: 0.0256
# Epoch: 89, loss: 0.0168
# Epoch: 90, loss: 0.0505
# Epoch: 91, loss: 0.02
# Epoch: 92, loss: 0.0267
# Epoch: 93, loss: 0.0169
# Epoch: 94, loss: 0.0195
# Epoch: 95, loss: 0.0226
# Epoch: 96, loss: 0.0604
# Epoch: 97, loss: 0.0165
# Epoch: 98, loss: 0.0181
# Epoch: 99, loss: 0.0197

# %% [markdown]
# ### Ewaluacja

# %%
test_dataset = XORDataset(size=500)
# drop_last -> Don't drop the last batch although it is smaller than 128
test_data_loader = data.DataLoader(test_dataset, batch_size=128, shuffle=False, drop_last=False)

# %%
model.eval() # Set model to eval mode
true_preds, num_preds = 0., 0.

with torch.no_grad(): # Deactivate gradients for the following code
    for data_inputs, data_labels in data_loader:

        # Determine prediction of model on dev set
        data_inputs, data_labels = data_inputs.to(device), data_labels.to(device)
        preds = model(data_inputs)
        preds = preds.squeeze(dim=1)
        preds = torch.sigmoid(preds) # Sigmoid to map predictions between 0 and 1
        pred_labels = (preds >= 0.5).long() # Binarize predictions to 0 and 1

        # Keep records of predictions for the accuracy metric (true_preds=TP+TN, num_preds=TP+TN+FP+FN)
        true_preds += (pred_labels == data_labels).sum()
        num_preds += data_labels.shape[0]

acc = true_preds / num_preds
print(f"Accuracy of the model: {100.0*acc:4.2f}%")
# Out:
# Accuracy of the model: 100.00%

# %%
from matplotlib.colors import to_rgba

# %%
with torch.no_grad():
    data = test_dataset.data.cpu().numpy()
    label = test_dataset.label.cpu().numpy()
    data_0 = data[label == 0]
    data_1 = data[label == 1]

    plt.figure(figsize=(4,4))
    plt.scatter(data_0[:,0], data_0[:,1], edgecolor="#333", label="Class 0")
    plt.scatter(data_1[:,0], data_1[:,1], edgecolor="#333", label="Class 1")
    plt.title("Dataset samples")
    plt.ylabel(r"$x_2$")
    plt.xlabel(r"$x_1$")
    plt.legend()

    # Let's make use of a lot of operations we have learned above
    model.to(device)
    c0 = torch.Tensor(to_rgba("C0")).to(device)
    c1 = torch.Tensor(to_rgba("C1")).to(device)
    x1 = torch.arange(-0.5, 1.5, step=0.01, device=device)
    x2 = torch.arange(-0.5, 1.5, step=0.01, device=device)
    xx1, xx2 = torch.meshgrid(x1, x2) # Meshgrid function as in numpy
    model_inputs = torch.stack([xx1, xx2], dim=-1)
    preds = model(model_inputs)
    preds = torch.sigmoid(preds)
    output_image = preds * c0[None,None] + (1 - preds) * c1[None,None] # Specifying "None" in a dimension creates a new one
    output_image = output_image.cpu().numpy() # Convert to numpy array. This only works for tensors on CPU, hence first push to CPU
    plt.imshow(output_image, origin='upper', extent=(-0.5, 1.5, -0.5, 1.5))
    plt.grid(False)
# Out:
# <img src="data:image/png;base64,..." width="399.65218219865267">

# %% [markdown]
# ## Zapisywanie i wczytywanie modelu

# %%
state_dict = model.state_dict()
print(state_dict)
# Out:
# OrderedDict([('linear1.weight', tensor([[-0.0106,  0.1316],
#         [ 3.2329, -3.5828],
#         [-0.2226,  0.1380],
#         [ 3.1477, -3.1794]], device='cuda:0')), ('linear1.bias', tensor([ 1.3514, -1.6153,  0.9173,  1.5365], device='cuda:0')), ('linear2.weight', tensor([[ 1.7440,  5.0300,  1.2046, -4.9042]], device='cuda:0')), ('linear2.bias', tensor([2.2341], device='cuda:0'))])

# %%
torch.save(state_dict, "simple_model.tar")

# %%
# Load state dict from the disk (make sure it is the same name as above)
state_dict = torch.load("simple_model.tar")

# Create a new model and load the state
new_model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
new_model.load_state_dict(state_dict)

# Verify that the parameters are the same
print("Original model\n", model.cpu().state_dict())
print("\nLoaded model\n", new_model.state_dict())
# Out:
# Original model
#  OrderedDict([('linear1.weight', tensor([[-0.0106,  0.1316],
#         [ 3.2329, -3.5828],
#         [-0.2226,  0.1380],
#         [ 3.1477, -3.1794]])), ('linear1.bias', tensor([ 1.3514, -1.6153,  0.9173,  1.5365])), ('linear2.weight', tensor([[ 1.7440,  5.0300,  1.2046, -4.9042]])), ('linear2.bias', tensor([2.2341]))])
#
# Loaded model
#  OrderedDict([('linear1.weight', tensor([[-0.0106,  0.1316],
#         [ 3.2329, -3.5828],
#         [-0.2226,  0.1380],
#         [ 3.1477, -3.1794]])), ('linear1.bias', tensor([ 1.3514, -1.6153,  0.9173,  1.5365])), ('linear2.weight', tensor([[ 1.7440,  5.0300,  1.2046, -4.9042]])), ('linear2.bias', tensor([2.2341]))])

# %% [markdown]
# ## Zrób to sam:
#
# Spróbujmy przewidzieć ocenę wina na podstawie jego parametrów

# %%
import pandas as pd
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', delimiter=";")

# %% [markdown]
# #### ... Jakieś wstępne przetwarzanie danych?

# %%
train=df.sample(frac=0.8,random_state=200) #random state is a seed value
test=df.drop(train.index)

# %%
import torch.utils.data as data

# %%
train_dataset = data.TensorDataset(torch.from_numpy(train.values[:,:-1]),torch.from_numpy(train.values[:,-1]))
next(iter(train_dataset))
# Out:
# (tensor([7.6000e+00, 3.0000e-01, 3.7000e-01, 1.6000e+00, 8.7000e-02, 2.7000e+01,
#          1.7700e+02, 9.9438e-01, 3.0900e+00, 5.0000e-01, 9.8000e+00],
#         dtype=torch.float64),
#  tensor(5., dtype=torch.float64))
