# %% [markdown]
# # GPU

# %% [markdown]
# ## Importy

# %%
import torch
import numpy as np
import time
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cuda

# %% [markdown]
# + Jednym z kluczowych udogodnień pytorcha jest możliwość szybkiego i prostego przenoszenia obliczeń między CPU a GPU.

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %%
x = torch.zeros(2, 3)
print("X", x)
x = x.to(device)
print("X", x)
# Out:
# X tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# X tensor([[0., 0., 0.],
#         [0., 0., 0.]], device='cuda:0')

# %% [markdown]
# + Co nam to daje - porównanie mnożenia macierzy 10000x10000

# %%
x = torch.randn(10000, 10000)

## CPU version
start_time = time.time()
_ = torch.matmul(x, x)
end_time = time.time()
print(f"CPU time: {(end_time - start_time):6.5f}s")

## GPU version
x = x.to(device)
# The first operation on a CUDA device can be slow as it has to establish a CPU-GPU communication first.
# Hence, we run an arbitrary command first without timing it for a fair comparison.
_ = torch.matmul(x * 0.0, x)
start_time = time.time()
_ = torch.matmul(x, x)
end_time = time.time()
print(f"GPU time: {(end_time - start_time):6.5f}s")
# Out:
# CPU time: 5.18924s
# GPU time: 0.00000s

# %% [markdown]
# + Ciąg komend do zapisania:
#     + Losowość jest bardzo ważnym elementem trenowania sieci neuronowych (o czym się wkrótce przekonamy).
#     + Eksperymentując, chcielibyśmy jednak żeby przy każdym uruchomieniu programu, wynik był taki sam. Tylko w takim przypadku jesteśmy w stanie coś wnioskować.
#     + Do zapewnienia możliwości reprodukcji wyników na GPU za pomocą pytorcha służa poniższe komendy:

# %%
# GPU operations have a separate seed we also want to set
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

# Additionally, some operations on a GPU are implemented stochastic for efficiency
# We want to ensure that all operations are deterministic on GPU (if used) for reproducibility
torch.backends.cudnn.determinstic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Tworzenie modeli

# %% [markdown]
# + Tworzymy tensory z parametrami, wagi i biasy, obliczamy gradienty, aktualizujemy parametry itd. lub wykorzystujemy torch.nn.
# + W torch.nn możemy znaleźć wiele przydatnych predefiniowanych klas jak wagi sieci, funkcje aktywacji, funkcje straty, optymalizacja itp.
# + Dokumentacja: https://pytorch.org/docs/stable/nn.html
# + Dodatkowo, funkcje wykorzystywane w budowaniu sieci znajdują się w module torch.nn.functional.

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# + W PyTorchu, sieci neuronowe są zbudowane z modułów - obiektów klas dziedziczących po klasie nn.Module. Moduły mogą składać się z innych modułów, a sieć neuronowa w całości też zazwyczaj jest modułem.
#
# + Podstawowy template dla modułu wygląda następująco:

# %%
class MyModule(nn.Module):
    def __init__(self):
        super().__init__()
        # Some init for my module

    def forward(self, x):
        # Function for performing the calculation of the module.
        pass

# %% [markdown]
# + W konstruktorze modułu zazwyczaj inicjowane są wszystkie parametry, lub wewnętrzne moduły (np. warstwy sieci).
#
# + W funkcji forward zapisane są wszystkie obliczenia które są wykonywane kiedy wywołujemy dany moduł.
#     + Przykładowo: (nn = MyModule(); nn(x)).
#
# + Kalkulacja wstecz (backwards) jest tworzona automatycznie, ale w razie potrzeby można ją też nadpisywać.

# %% [markdown]
# # Pierwsza sieć neuronowa

# %% [markdown]
# + Prosty klasyfikator o 1 warstwie ukrytej:

# %%
class SimpleClassifier(nn.Module):
    def __init__(self, num_inputs, num_hidden, num_outputs):
        super().__init__()
        # Initialize the modules we need to build the network
        self.linear1 = nn.Linear(num_inputs, num_hidden)
        self.act_fn = nn.Tanh()
        self.linear2 = nn.Linear(num_hidden, num_outputs)

    def forward(self, x):
        # Perform the calculation of the model to determine the prediction
        x = self.linear1(x)
        x = self.act_fn(x)
        x = self.linear2(x)
        return x

# %% [markdown]
# + Wypisywanie zawartości modelu:

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
# Printing a module shows all its submodules
print(model)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %% [markdown]
# + Co jest w środku:

# %%
for name, param in model.named_parameters():
    print(f"Parameter {name}, shape {param.shape}")
# Out:
# Parameter linear1.weight, shape torch.Size([4, 2])
# Parameter linear1.bias, shape torch.Size([4])
# Parameter linear2.weight, shape torch.Size([1, 4])
# Parameter linear2.bias, shape torch.Size([1])

# %% [markdown]
# # Funkcje aktywacji

# %% [markdown]
# + Przykładowe:

# %%
act_fn_by_name = {
    "sigmoid": torch.sigmoid,
    "tanh": torch.tanh,
    "relu": F.relu,
    "leakyrelu": F.leaky_relu
}

# %% [markdown]
# + Funkcja pokazująca gradient:

# %%
# function returns gradient of x depending of activation function
def get_grads(act_fn, x):
    x = x.clone().requires_grad_(
    )  # Mark the input as tensor for which we want to store gradients
    out = act_fn(x)
    out.sum().backward(
    )  # Summing results in an equal gradient flow to each element in x
    return x.grad  # Accessing the gradients of x by "x.grad"

# %% [markdown]
# + Podstawowe funkcje i ich gradienty:

# %%
# %matplotlib inline
def vis_act_fn(act_fn, name, ax, x):
    # Run activation function
    y = act_fn(x)
    y_grads = get_grads(act_fn, x)
    # Push x, y and gradients back to cpu for plotting
    x, y, y_grads = x.cpu().numpy(), y.cpu().numpy(), y_grads.cpu().numpy()
    ## Plotting
    ax.plot(x, y, linewidth=2, label="ActFn")
    ax.plot(x, y_grads, linewidth=2, label="Gradient")
    ax.set_title(name)
    ax.legend()
    ax.set_ylim(-1.5, x.max())


x = torch.linspace(
    -5, 5,
    1000)  # Range on which we want to visualize the activation functions
## Plotting
rows = math.ceil(len(act_fn_by_name) / 2.0)
fig, ax = plt.subplots(rows, 2, figsize=(8, rows * 4))
for i, name in enumerate(act_fn_by_name.keys()):
    vis_act_fn(act_fn_by_name[name], name, ax[divmod(i, 2)], x)
fig.subplots_adjust(hspace=0.3)
plt.show()
plt.close()

# %% [markdown]
# # Dane

# %% [markdown]
# + PyTorch posiada zaimplementowanych kilka funkcjonalności które pozwalają wczytywać i manipulować danymi. Znajdują się one w pakiecie torch.utils.data

# %%
import torch.utils.data as data

# %% [markdown]
# ## Dataset
# + Główną strukturą w ramach której przechowywane (lub niekoniecznie) są dane jest klasa Dataset. Stwórzmy sobie przykładowy zbiór danych - tzw. ciągły XOR.
# + Przykład zaczerpnięty z https://uvadlc-notebooks.readthedocs.io/en/latest/tutorial_notebooks/tutorial2/Introduction_to_PyTorch.html#Learning-by-example:-Continuous-XOR

# %%
class XORDataset(data.Dataset):
    def __init__(self, size, std=0.1):
        """
        Inputs:
            size - Number of data points we want to generate
            std - Standard deviation of the noise (see generate_continuous_xor function)
        """
        super().__init__()
        self.size = size
        self.std = std
        self.generate_continuous_xor()

    def generate_continuous_xor(self):
        # Each data point in the XOR dataset has two variables, x and y, that can be either 0 or 1
        # The label is their XOR combination, i.e. 1 if only x or only y is 1 while the other is 0.
        # If x=y, the label is 0.
        data = torch.randint(low=0,
                             high=2,
                             size=(self.size, 2),
                             dtype=torch.float32)
        label = (data.sum(dim=1) == 1).to(torch.long)
        # To make it slightly more challenging, we add a bit of gaussian noise to the data points.
        data += self.std * torch.randn(data.shape)

        self.data = data
        self.label = label

    def __len__(self):
        # Number of data point we have. Alternatively self.data.shape[0], or self.label.shape[0]
        return self.size

    def __getitem__(self, idx):
        # Return the idx-th data point of the dataset
        # If we have multiple things to return (data point and label), we can return them as tuple
        data_point = self.data[idx]
        data_label = self.label[idx]
        return data_point, data_label

# %%
dataset = XORDataset(size=200)
print("Size of dataset:", len(dataset))
print("Data point 0:", dataset[0])
# Out:
# Size of dataset: 200
# Data point 0: (tensor([0.9736, 0.9861]), tensor(0))

# %%
examples = dataset.data
labels = dataset.label
data_0 = examples[labels == 0]
data_1 = examples[labels == 1]

plt.figure(figsize=(4, 4))
plt.scatter(data_0[:, 0], data_0[:, 1], edgecolor="#333", label="Class 0")
plt.scatter(data_1[:, 0], data_1[:, 1], edgecolor="#333", label="Class 1")
plt.title("Dataset samples")
plt.legend()
plt.show()

# %% [markdown]
# ## Data loaders

# %% [markdown]
# + Służą do ładowania danych i dzieleniu ich na batche:

# %%
data_loader = data.DataLoader(dataset, batch_size=8, shuffle=True)

# %%
next(iter(data_loader))
# Out:
# [tensor([[ 1.0814, -0.0502],
#          [ 1.0970,  0.9348],
#          [ 0.9569,  0.8441],
#          [ 0.8118, -0.0913],
#          [ 1.0759,  0.9869],
#          [-0.0481,  0.0933],
#          [ 0.9853,  1.0301],
#          [ 1.0098,  0.8712]]),
#  tensor([1, 0, 0, 1, 0, 0, 0, 0])]

# %%
len(data_loader)  # ile batchy
# Out:
# 25

# %%
iter(data_loader)

# %%
next(iter(data_loader))[0].shape[0] * len(data_loader)
# Out:
# 200

# %%
data_loader_2 = data.DataLoader(dataset, batch_size=7, shuffle=True)
next(iter(data_loader_2))[0].shape[0] * len(data_loader_2)
# Out:
# 203

# %% [markdown]
# + Można zauważyć że nie ma dokładnie tyle danych ile jest batchy * rozmiar batcha.
# + Oznacza to, że ostatni z batchy jest mniejszy niż pozostałe:

# %%
list(iter(data_loader_2))[-1]
# Out:
# [tensor([[ 0.0020, -0.0958],
#          [ 1.0131,  0.8971],
#          [ 1.0286, -0.0313],
#          [ 0.0884,  0.8243]]),
#  tensor([0, 0, 1, 1])]

# %% [markdown]
# + drop_last - parametr powodujący pominięcie ostatniego wsadu (batch):

# %%
data_loader_2 = data.DataLoader(dataset,
                                batch_size=7,
                                shuffle=True,
                                drop_last=True)
next(iter(data_loader_2))[0].shape[0] * len(data_loader_2)
# Out:
# 196

# %% [markdown]
# # Funkcje straty

# %% [markdown]
# + Można wykorzystać wbudowane moduły.
# + Pełna lista dostępna tutaj: https://pytorch.org/docs/stable/nn.html#loss-functions

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tensor_1 = torch.arange(5)
tensor_2 = torch.ones(5)
print(tensor_1, tensor_2)
# Out:
# tensor([0, 1, 2, 3, 4]) tensor([1., 1., 1., 1., 1.])

# %% [markdown]
# ## Błąd średniokwadratowy
# +  (Mean Squared Error lub L2Loss)
# $ \quad l_{n}=\left(x_{n}-y_{n}\right)^{2}$

# %%
loss = nn.MSELoss()
loss(tensor_1, tensor_2)
# Out:
# tensor(3.)

# %%
loss = nn.MSELoss(reduction="none")
print(f"No reduction: {loss(tensor_1,tensor_2)}")
loss = nn.MSELoss(reduction="mean")
print(f"Mean: {loss(tensor_1,tensor_2)}")
loss = nn.MSELoss(reduction="sum")
print(f"Sum: {loss(tensor_1,tensor_2)}")
# Out:
# No reduction: tensor([1., 0., 1., 4., 9.])
# Mean: 3.0
# Sum: 15.0

# %%
F.mse_loss(tensor_1, tensor_2)
# Out:
# tensor(3.)

# %% [markdown]
# + wykres w 3D:

# %%
loss = nn.MSELoss(reduction="none")
x, y = torch.meshgrid(torch.linspace(0, 10, 100), torch.linspace(0, 10, 100))
z = loss(x, y)

fig = plt.figure()
# ax = fig.gca(projection='3d')
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(),
                y.numpy().flatten(),
                z.numpy().flatten(),
                linewidth=0.2,
                antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="792.2087219307517">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_21860/2132022299.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Błąd bezwzględny
# + Mean absolute Error lub L1Loss
# $ \quad l_{n}=\left|x_{n}-y_{n}\right|$

# %%
print(tensor_1, tensor_2)
loss = nn.L1Loss()
tensor_1 = tensor_1.float()
loss(tensor_1, tensor_2)
# Out:
# tensor([0, 1, 2, 3, 4]) tensor([1., 1., 1., 1., 1.])
# tensor(1.4000)

# %%
loss = nn.L1Loss(reduction="none")
print(f"No reduction: {loss(tensor_1,tensor_2)}")
loss = nn.L1Loss(reduction="mean")
print(f"Mean: {loss(tensor_1,tensor_2)}")
loss = nn.L1Loss(reduction="sum")
print(f"Sum: {loss(tensor_1,tensor_2)}")
# Out:
# No reduction: tensor([1., 0., 1., 2., 3.])
# Mean: 1.399999976158142
# Sum: 7.0

# %% [markdown]
# + Wykres 3D:

# %%
loss = nn.L1Loss(reduction="none")
x, y = torch.meshgrid(torch.linspace(0, 10, 100), torch.linspace(0, 10, 100))
z = loss(x, y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(),
                y.numpy().flatten(),
                z.numpy().flatten(),
                linewidth=0.2,
                antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="812.2435052040267">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_21860/2569845650.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Entropia krzyżowa:
# + Cross Entropy
# $l_{n}=\left[y_{n} \cdot \log x_{n}+\left(1-y_{n}\right) \cdot \log \left(1-x_{n}\right)\right]$

# %%
tensor_1 = torch.rand(5).float()
tensor_2 = torch.ones(5).float()
print(tensor_1, tensor_2)
loss = nn.BCELoss(reduction="none")
loss(tensor_1, tensor_2)
# Out:
# tensor([0.4682, 0.9704, 0.6381, 0.4482, 0.1412]) tensor([1., 1., 1., 1., 1.])
# tensor([0.7589, 0.0300, 0.4493, 0.8024, 1.9572])

# %% [markdown]
# + Użycie entropii z BCELoss() nie pozwala na wartości nie należące to (0,1)

# %%
loss(tensor_1 * 10, tensor_2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21860/1382492310.py in <module>
# ----> 1 loss(tensor_1 * 10, tensor_2)
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     610
#     611     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 612         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     613
#     614
#
# c:\users\01149762\documents\ai\neural-networks-intro\venv\lib\site-packages\torch\nn\functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2891         weight = weight.expand(new_size)
#    2892
# -> 2893     return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#    2894
#    2895
#
# RuntimeError: all elements of input should be between 0 and 1

# %% [markdown]
# + BCEWithLogitsLoss() natomiast działa:

# %%
loss = nn.BCEWithLogitsLoss(reduction="none")
loss(tensor_1 * 10, tensor_2)
# Out:
# tensor([9.2192e-03, 6.1033e-05, 1.6923e-03, 1.1242e-02, 2.1796e-01])

# %% [markdown]
# + Wykres 3D:

# %%
loss = nn.BCEWithLogitsLoss(reduction="none")
x, y = torch.meshgrid(torch.linspace(-10, 10, 100),
                      torch.linspace(-10, 10, 100))
z = loss(x, y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x.numpy().flatten(),
                y.numpy().flatten(),
                z.numpy().flatten(),
                linewidth=0.2,
                antialiased=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="813.9130704767997">
# C:\Users\01149762\AppData\Local\Temp/ipykernel_21860/1728708762.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# # Optymalizacja parametrów

# %% [markdown]
# + W torch do optymalizacji prametrów są narzędzia zwane optymalizatorami, znajdują się one w pakiecie torch.optim.
#
# + Najprostszym optymalizaotrem jest algorytm stochastycznego spadku gradientu (Stochastic Gradient Descent) - SGD.

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
print(model)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# # Przykładowy problem

# %% [markdown]
# ## Zebranie danych

# %%
train_dataset = XORDataset(size=1000)
train_data_loader = data.DataLoader(train_dataset,
                                    batch_size=128,
                                    shuffle=True)

# %% [markdown]
# + Przykładowa próbka:

# %%
train_dataset[2]
# Out:
# (tensor([1.0721, 0.0013]), tensor(1))

# %% [markdown]
# ## Stworzenie klasyfikatora
# + Wraz z przeniesieniem go na GPU (jego parametrów).

# %%
model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
model.to(device)
# Out:
# SimpleClassifier(
#   (linear1): Linear(in_features=2, out_features=4, bias=True)
#   (act_fn): Tanh()
#   (linear2): Linear(in_features=4, out_features=1, bias=True)
# )

# %% [markdown]
# ## Optymalizzator + funkcja straty

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
loss_module = nn.BCEWithLogitsLoss()

# %% [markdown]
# ## Trenowanie modelu

# %%
model.train()

# Training loop
for epoch in range(100):
    for data_inputs, data_labels in data_loader:

        ## Step 1: Move input data to device (only strictly necessary if we use GPU)
        data_inputs = data_inputs.to(device)
        data_labels = data_labels.to(device)

        ## Step 2: Run the model on the input data
        preds = model(data_inputs)
        preds = preds.squeeze(
            dim=1)  # Output is [Batch size, 1], but we want [Batch size]

        ## Step 3: Calculate the loss
        loss = loss_module(preds, data_labels.float())

        ## Step 4: Perform backpropagation
        # Before calculating the gradients, we need to ensure that they are all zero.
        # The gradients would not be overwritten, but actually added to the existing ones.
        optimizer.zero_grad()
        # Perform backpropagation
        loss.backward()

        ## Step 5: Update the parameters
        optimizer.step()
    print(f"Epoch: {epoch}, loss: {loss.item():.3}")
# Out:
# Epoch: 0, loss: 0.696
# Epoch: 1, loss: 0.693
# Epoch: 2, loss: 0.687
# Epoch: 3, loss: 0.657
# Epoch: 4, loss: 0.716
# Epoch: 5, loss: 0.706
# Epoch: 6, loss: 0.684
# Epoch: 7, loss: 0.729
# Epoch: 8, loss: 0.749
# Epoch: 9, loss: 0.694
# Epoch: 10, loss: 0.704
# Epoch: 11, loss: 0.713
# Epoch: 12, loss: 0.634
# Epoch: 13, loss: 0.666
# Epoch: 14, loss: 0.706
# Epoch: 15, loss: 0.694
# Epoch: 16, loss: 0.636
# Epoch: 17, loss: 0.613
# Epoch: 18, loss: 0.676
# Epoch: 19, loss: 0.705
# Epoch: 20, loss: 0.677
# Epoch: 21, loss: 0.659
# Epoch: 22, loss: 0.639
# Epoch: 23, loss: 0.602
# Epoch: 24, loss: 0.629
# Epoch: 25, loss: 0.558
# Epoch: 26, loss: 0.51
# Epoch: 27, loss: 0.491
# Epoch: 28, loss: 0.538
# Epoch: 29, loss: 0.466
# Epoch: 30, loss: 0.526
# Epoch: 31, loss: 0.455
# Epoch: 32, loss: 0.358
# Epoch: 33, loss: 0.27
# Epoch: 34, loss: 0.28
# Epoch: 35, loss: 0.3
# Epoch: 36, loss: 0.263
# Epoch: 37, loss: 0.242
# Epoch: 38, loss: 0.201
# Epoch: 39, loss: 0.146
# Epoch: 40, loss: 0.185
# Epoch: 41, loss: 0.184
# Epoch: 42, loss: 0.13
# Epoch: 43, loss: 0.128
# Epoch: 44, loss: 0.117
# Epoch: 45, loss: 0.111
# Epoch: 46, loss: 0.111
# Epoch: 47, loss: 0.0933
# Epoch: 48, loss: 0.0918
# Epoch: 49, loss: 0.0812
# Epoch: 50, loss: 0.073
# Epoch: 51, loss: 0.0733
# Epoch: 52, loss: 0.0484
# Epoch: 53, loss: 0.0638
# Epoch: 54, loss: 0.0652
# Epoch: 55, loss: 0.0557
# Epoch: 56, loss: 0.0627
# Epoch: 57, loss: 0.0335
# Epoch: 58, loss: 0.0432
# Epoch: 59, loss: 0.0328
# Epoch: 60, loss: 0.0312
# Epoch: 61, loss: 0.0498
# Epoch: 62, loss: 0.0384
# Epoch: 63, loss: 0.0498
# Epoch: 64, loss: 0.0392
# Epoch: 65, loss: 0.0244
# Epoch: 66, loss: 0.0357
# Epoch: 67, loss: 0.0339
# Epoch: 68, loss: 0.0274
# Epoch: 69, loss: 0.0328
# Epoch: 70, loss: 0.0298
# Epoch: 71, loss: 0.0274
# Epoch: 72, loss: 0.0366
# Epoch: 73, loss: 0.0262
# Epoch: 74, loss: 0.0285
# Epoch: 75, loss: 0.0262
# Epoch: 76, loss: 0.0306
# Epoch: 77, loss: 0.0186
# Epoch: 78, loss: 0.0278
# Epoch: 79, loss: 0.0244
# Epoch: 80, loss: 0.0261
# Epoch: 81, loss: 0.019
# Epoch: 82, loss: 0.0166
# Epoch: 83, loss: 0.0237
# Epoch: 84, loss: 0.0183
# Epoch: 85, loss: 0.0254
# Epoch: 86, loss: 0.0193
# Epoch: 87, loss: 0.0255
# Epoch: 88, loss: 0.0212
# Epoch: 89, loss: 0.0199
# Epoch: 90, loss: 0.0131
# Epoch: 91, loss: 0.0169
# Epoch: 92, loss: 0.0174
# Epoch: 93, loss: 0.015
# Epoch: 94, loss: 0.0225
# Epoch: 95, loss: 0.0176
# Epoch: 96, loss: 0.0184
# Epoch: 97, loss: 0.0156
# Epoch: 98, loss: 0.0163
# Epoch: 99, loss: 0.0155

# %% [markdown]
# ## Ewaluacja wyników

# %%
test_dataset = XORDataset(size=500)
# drop_last -> Don't drop the last batch although it is smaller than 128
test_data_loader = data.DataLoader(test_dataset,
                                   batch_size=128,
                                   shuffle=False,
                                   drop_last=False)

# %%
model.eval()  # Set model to eval mode
true_preds, num_preds = 0., 0.

with torch.no_grad():  # Deactivate gradients for the following code
    for data_inputs, data_labels in data_loader:

        # Determine prediction of model on dev set
        data_inputs, data_labels = data_inputs.to(device), data_labels.to(
            device)
        preds = model(data_inputs)
        preds = preds.squeeze(dim=1)
        preds = torch.sigmoid(
            preds)  # Sigmoid to map predictions between 0 and 1
        pred_labels = (preds >= 0.5).long()  # Binarize predictions to 0 and 1

        # Keep records of predictions for the accuracy metric (true_preds=TP+TN, num_preds=TP+TN+FP+FN)
        true_preds += (pred_labels == data_labels).sum()
        num_preds += data_labels.shape[0]

acc = true_preds / num_preds
print(f"Accuracy of the model: {100.0*acc:4.2f}%")
# Out:
# Accuracy of the model: 100.00%

# %% [markdown]
# ## Wizualizacja wyników

# %%
from matplotlib.colors import to_rgba

# %%
with torch.no_grad():
    data = test_dataset.data.cpu().numpy()
    label = test_dataset.label.cpu().numpy()
    data_0 = data[label == 0]
    data_1 = data[label == 1]

    plt.figure(figsize=(4, 4))
    plt.scatter(data_0[:, 0], data_0[:, 1], edgecolor="#333", label="Class 0")
    plt.scatter(data_1[:, 0], data_1[:, 1], edgecolor="#333", label="Class 1")
    plt.title("Dataset samples")
    plt.ylabel(r"$x_2$")
    plt.xlabel(r"$x_1$")
    plt.legend()

    # Let's make use of a lot of operations we have learned above
    model.to(device)
    c0 = torch.Tensor(to_rgba("C0")).to(device)
    c1 = torch.Tensor(to_rgba("C1")).to(device)
    x1 = torch.arange(-0.5, 1.5, step=0.01, device=device)
    x2 = torch.arange(-0.5, 1.5, step=0.01, device=device)
    xx1, xx2 = torch.meshgrid(x1, x2)  # Meshgrid function as in numpy
    model_inputs = torch.stack([xx1, xx2], dim=-1)
    preds = model(model_inputs)
    preds = torch.sigmoid(preds)
    output_image = preds * c0[None, None] + (1 - preds) * c1[
        None, None]  # Specifying "None" in a dimension creates a new one
    output_image = output_image.cpu().numpy(
    )  # Convert to numpy array. This only works for tensors on CPU, hence first push to CPU
    plt.imshow(output_image, origin='upper', extent=(-0.5, 1.5, -0.5, 1.5))
    plt.grid(False)
# Out:
# <img src="data:image/png;base64,..." width="343.930446191222">

# %% [markdown]
# # Zapisywanie i wczytywanie modelu

# %% [markdown]
# + Na przykładzie z poprzedniego punktu.

# %% [markdown]
# ## Zapisanie modelu

# %%
state_dict = model.state_dict()
print(state_dict)
# Out:
# OrderedDict([('linear1.weight', tensor([[-3.2911,  2.4977],
#         [-0.2877,  1.7880],
#         [-1.6479,  2.9554],
#         [ 2.7303,  2.8101]], device='cuda:0')), ('linear1.bias', tensor([-0.9706, -0.4977,  0.4068, -0.7849], device='cuda:0')), ('linear2.weight', tensor([[ 4.6321, -1.8635, -3.4241,  4.0784]], device='cuda:0')), ('linear2.bias', tensor([0.9991], device='cuda:0'))])

# %%
torch.save(state_dict, "simple_model.tar")

# %% [markdown]
# ## Wczytanie modelu

# %%
# Load state dict from the disk (make sure it is the same name as above)
state_dict = torch.load("simple_model.tar")

# Create a new model and load the state
new_model = SimpleClassifier(num_inputs=2, num_hidden=4, num_outputs=1)
new_model.load_state_dict(state_dict)

# Verify that the parameters are the same
print("Original model\n", model.cpu().state_dict())
print("\nLoaded model\n", new_model.state_dict())
# Out:
# Original model
#  OrderedDict([('linear1.weight', tensor([[-3.2911,  2.4977],
#         [-0.2877,  1.7880],
#         [-1.6479,  2.9554],
#         [ 2.7303,  2.8101]])), ('linear1.bias', tensor([-0.9706, -0.4977,  0.4068, -0.7849])), ('linear2.weight', tensor([[ 4.6321, -1.8635, -3.4241,  4.0784]])), ('linear2.bias', tensor([0.9991]))])
#
# Loaded model
#  OrderedDict([('linear1.weight', tensor([[-3.2911,  2.4977],
#         [-0.2877,  1.7880],
#         [-1.6479,  2.9554],
#         [ 2.7303,  2.8101]])), ('linear1.bias', tensor([-0.9706, -0.4977,  0.4068, -0.7849])), ('linear2.weight', tensor([[ 4.6321, -1.8635, -3.4241,  4.0784]])), ('linear2.bias', tensor([0.9991]))])
